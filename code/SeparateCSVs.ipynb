# %% [markdown]
# # Create Separate CSV files for each model
# This notebook uses the master data file for the surrogate model from [`all_sources_together.csv`]() and creates six separate `.csv` files, one for each interpolation model. We have six outcome variables of interest, which we are predicting from the

# %%
# Import packages
import numpy as np
import pandas as pd
import os
